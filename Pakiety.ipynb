# %%
using Pkg

# %%
Pkg.add("DataFrames")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed Tables ────────────────────── v1.12.1
#    Installed DataAPI ───────────────────── v1.16.0
#    Installed PooledArrays ──────────────── v1.4.3
#    Installed SentinelArrays ────────────── v1.4.9
#    Installed TableTraits ───────────────── v1.0.1
#    Installed Crayons ───────────────────── v4.1.1
#    Installed InlineStrings ─────────────── v1.4.5
#    Installed DataValueInterfaces ───────── v1.0.0
#    Installed OrderedCollections ────────── v1.8.1
#    Installed Reexport ──────────────────── v1.2.2
#    Installed LaTeXStrings ──────────────── v1.4.0
#    Installed IteratorInterfaceExtensions ─ v1.0.0
#    Installed InvertedIndices ───────────── v1.3.1
#    Installed Compat ────────────────────── v4.18.1
#    Installed Statistics ────────────────── v1.11.1
#    Installed Missings ──────────────────── v1.2.0
#    Installed DataStructures ────────────── v0.19.3
#    Installed DataFrames ────────────────── v1.8.1
#    Installed PrettyTables ──────────────── v3.2.3
#    Installed StringManipulation ────────── v0.4.2
#    Installed SortingAlgorithms ─────────── v1.2.2
#     Updating `~/.julia/environments/v1.12/Project.toml`
#   [a93c6f00] + DataFrames v1.8.1
#     Updating `~/.julia/environments/v1.12/Manifest.toml`
#   [34da2185] + Compat v4.18.1
#   [a8cc5b0e] + Crayons v4.1.1
#   [9a962f9c] + DataAPI v1.16.0
#   [a93c6f00] + DataFrames v1.8.1
#   [864edb3b] + DataStructures v0.19.3
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [842dd82b] + InlineStrings v1.4.5
#   [41ab1584] + InvertedIndices v1.3.1
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [b964fa9f] + LaTeXStrings v1.4.0
#   [e1d29d7a] + Missings v1.2.0
#   [bac558e1] + OrderedCollections v1.8.1
#   [2dfb63ee] + PooledArrays v1.4.3
#   [08abe8d2] + PrettyTables v3.2.3
#   [189a3867] + Reexport v1.2.2
#   [91c51154] + SentinelArrays v1.4.9
#   [a2af1166] + SortingAlgorithms v1.2.2
#   [10745b16] + Statistics v1.11.1
#   [892a3eda] + StringManipulation v0.4.2
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.12.1
#   [9fa8497b] + Future v1.11.0
#   [37e2e46d] + LinearAlgebra v1.12.0
#   [4536629a] + OpenBLAS_jll v0.3.29+0
#   [8e850b90] + libblastrampoline_jll v5.15.0+0
# Precompiling packages...
#    1026.8 ms  ✓ LaTeXStrings
#    1028.4 ms  ✓ DataValueInterfaces
#    1017.3 ms  ✓ DataAPI
#    1026.6 ms  ✓ InvertedIndices
#    1024.6 ms  ✓ Reexport
#    1019.8 ms  ✓ IteratorInterfaceExtensions
#    1289.6 ms  ✓ Statistics
#     608.8 ms  ✓ TableTraits
#    1675.5 ms  ✓ InlineStrings
#     827.9 ms  ✓ PooledArrays
#     630.0 ms  ✓ InlineStrings → ParsersExt
#    2621.0 ms  ✓ SentinelArrays
#    3118.1 ms  ✓ StringManipulation
#    3246.9 ms  ✓ OrderedCollections
#    3214.8 ms  ✓ Compat
#    2544.7 ms  ✓ Missings
#     510.6 ms  ✓ Compat → CompatLinearAlgebraExt
#    3780.6 ms  ✓ Crayons
#    1762.0 ms  ✓ DataStructures
#    2121.8 ms  ✓ Tables
#     546.8 ms  ✓ SortingAlgorithms
#     394.4 ms  ✓ StructUtils → StructUtilsTablesExt
#   22097.4 ms  ✓ PrettyTables
#   39523.8 ms  ✓ DataFrames
#   24 dependencies successfully precompiled in 68 seconds. 42 already precompiled.

# %%
using DataFrames

# %%
Pkg.add("CSV")
# Out:
#    Resolving package versions...
#    Installed CodecZlib ────────── v0.7.8
#    Installed WeakRefStrings ───── v1.4.2
#    Installed WorkerUtilities ──── v1.6.1
#    Installed FilePathsBase ────── v0.9.24
#    Installed TranscodingStreams ─ v0.11.3
#    Installed CSV ──────────────── v0.10.16
#   Installing 1 artifacts
#    Installed artifact testfiles 6.2 MiB
#     Updating `~/.julia/environments/v1.12/Project.toml`
#   [336ed68f] + CSV v0.10.16
#     Updating `~/.julia/environments/v1.12/Manifest.toml`
#   [336ed68f] + CSV v0.10.16
#   [944b1d66] + CodecZlib v0.7.8
#   [48062228] + FilePathsBase v0.9.24
#   [3bb67fe8] + TranscodingStreams v0.11.3
#   [ea10d353] + WeakRefStrings v1.4.2
#   [76eceee3] + WorkerUtilities v1.6.1
#   [a63ad114] + Mmap v1.11.0
# Precompiling packages...
#     548.6 ms  ✓ WorkerUtilities
#     676.7 ms  ✓ TranscodingStreams
#     947.7 ms  ✓ WeakRefStrings
#    1181.8 ms  ✓ FilePathsBase
#     499.1 ms  ✓ CodecZlib
#     450.1 ms  ✓ FilePathsBase → FilePathsBaseMmapExt
#   14159.3 ms  ✓ CSV
#   7 dependencies successfully precompiled in 16 seconds. 67 already precompiled.

# %%
using CSV

# %%
Pkg.add("Plots")
# Out:
#    Resolving package versions...
#    Installed libdecor_jll ───────────────── v0.2.2+0
#    Installed x265_jll ───────────────────── v4.1.0+0
#    Installed libfdk_aac_jll ─────────────── v2.0.4+0
#    Installed Libmount_jll ───────────────── v2.41.3+0
#    Installed LERC_jll ───────────────────── v4.0.1+0
#    Installed JpegTurbo_jll ──────────────── v3.1.4+0
#    Installed GR_jll ─────────────────────── v0.73.22+0
#    Installed LoggingExtras ──────────────── v1.2.0
#    Installed RelocatableFolders ─────────── v1.0.1
#    Installed Xorg_xkbcomp_jll ───────────── v1.4.7+0
#    Installed Measures ───────────────────── v0.3.3
#    Installed GR ─────────────────────────── v0.73.22
#    Installed Opus_jll ───────────────────── v1.6.1+0
#    Installed Contour ────────────────────── v0.6.3
#    Installed ConcurrentUtilities ────────── v2.5.1
#    Installed Grisu ──────────────────────── v1.0.2
#    Installed Xorg_xcb_util_wm_jll ───────── v0.4.2+0
#    Installed Xorg_xcb_util_image_jll ────── v0.4.1+0
#    Installed RecipesPipeline ────────────── v0.6.12
#    Installed PlotUtils ──────────────────── v1.4.4
#    Installed DelimitedFiles ─────────────── v1.9.1
#    Installed OpenSSL ────────────────────── v1.6.1
#    Installed Xorg_xcb_util_jll ──────────── v0.4.1+0
#    Installed Xorg_libSM_jll ─────────────── v1.2.6+0
#    Installed Fontconfig_jll ─────────────── v2.17.1+0
#    Installed Cairo_jll ──────────────────── v1.18.5+1
#    Installed Xorg_libxkbfile_jll ────────── v1.2.0+0
#    Installed HTTP ───────────────────────── v1.10.19
#    Installed Xorg_libXinerama_jll ───────── v1.1.7+0
#    Installed Xorg_libXau_jll ────────────── v1.0.13+0
#    Installed EpollShim_jll ──────────────── v0.0.20230411+1
#    Installed FFMPEG ─────────────────────── v0.4.5
#    Installed IrrationalConstants ────────── v0.2.6
#    Installed Showoff ────────────────────── v1.0.3
#    Installed Pango_jll ──────────────────── v1.57.0+0
#    Installed Xorg_xcb_util_keysyms_jll ──── v0.4.1+0
#    Installed xkbcommon_jll ──────────────── v1.13.0+0
#    Installed Bzip2_jll ──────────────────── v1.0.9+0
#    Installed PtrArrays ──────────────────── v1.3.0
#    Installed SimpleBufferStream ─────────── v1.2.0
#    Installed XZ_jll ─────────────────────── v5.8.2+0
#    Installed HarfBuzz_jll ───────────────── v8.5.1+0
#    Installed PlotThemes ─────────────────── v3.3.0
#    Installed fzf_jll ────────────────────── v0.61.1+0
#    Installed NaNMath ────────────────────── v1.1.3
#    Installed FriBidi_jll ────────────────── v1.0.17+0
#    Installed LZO_jll ────────────────────── v2.10.3+0
#    Installed UnicodeFun ─────────────────── v0.4.1
#    Installed GLFW_jll ───────────────────── v3.4.1+0
#    Installed x264_jll ───────────────────── v10164.0.1+0
#    Installed JLFzf ──────────────────────── v0.1.11
#    Installed MbedTLS ────────────────────── v1.1.9
#    Installed FreeType2_jll ──────────────── v2.13.4+0
#    Installed StatsAPI ───────────────────── v1.8.0
#    Installed Colors ─────────────────────── v0.13.1
#    Installed mtdev_jll ──────────────────── v1.1.7+0
#    Installed Xorg_libxcb_jll ────────────── v1.17.1+0
#    Installed StatsBase ──────────────────── v0.34.10
#    Installed libpng_jll ─────────────────── v1.6.55+0
#    Installed libaom_jll ─────────────────── v3.13.1+0
#    Installed ExceptionUnwrapping ────────── v0.1.11
#    Installed Scratch ────────────────────── v1.3.0
#    Installed ColorSchemes ───────────────── v3.31.0
#    Installed eudev_jll ──────────────────── v3.2.14+0
#    Installed Dbus_jll ───────────────────── v1.16.2+0
#    Installed ColorTypes ─────────────────── v0.12.1
#    Installed TensorCore ─────────────────── v0.1.1
#    Installed Xorg_xcb_util_cursor_jll ───── v0.1.6+0
#    Installed Xorg_libXext_jll ───────────── v1.3.8+0
#    Installed Zstd_jll ───────────────────── v1.5.7+1
#    Installed Plots ──────────────────────── v1.41.6
#    Installed Format ─────────────────────── v1.3.7
#    Installed Expat_jll ──────────────────── v2.7.3+0
#    Installed Libtiff_jll ────────────────── v4.7.2+0
#    Installed ColorVectorSpace ───────────── v0.11.0
#    Installed Xorg_libXrender_jll ────────── v0.9.12+0
#    Installed libinput_jll ───────────────── v1.28.1+0
#    Installed Libffi_jll ─────────────────── v3.4.7+0
#    Installed libevdev_jll ───────────────── v1.13.4+0
#    Installed Ogg_jll ────────────────────── v1.3.6+0
#    Installed Xorg_libXi_jll ─────────────── v1.8.3+0
#    Installed Vulkan_Loader_jll ──────────── v1.3.243+0
#    Installed Qt6ShaderTools_jll ─────────── v6.8.2+1
#    Installed Qt6Declarative_jll ─────────── v6.8.2+1
#    Installed LogExpFunctions ────────────── v0.3.29
#    Installed MacroTools ─────────────────── v0.5.16
#    Installed AliasTables ────────────────── v1.1.3
#    Installed Ghostscript_jll ────────────── v9.55.1+0
#    Installed MbedTLS_jll ────────────────── v2.28.1010+0
#    Installed Xorg_libXcursor_jll ────────── v1.2.4+0
#    Installed Libuuid_jll ────────────────── v2.41.3+0
#    Installed DocStringExtensions ────────── v0.9.5
#    Installed Xorg_xcb_util_renderutil_jll ─ v0.3.10+0
#    Installed Xorg_libICE_jll ────────────── v1.1.2+0
#    Installed libass_jll ─────────────────── v0.17.4+0
#    Installed StableRNGs ─────────────────── v1.0.4
#    Installed Graphite2_jll ──────────────── v1.3.15+0
#    Installed Wayland_jll ────────────────── v1.24.0+0
#    Installed Pixman_jll ─────────────────── v0.44.2+0
#    Installed Latexify ───────────────────── v0.16.10
#    Installed Xorg_xtrans_jll ────────────── v1.6.0+0
#    Installed BitFlags ───────────────────── v0.1.9
#    Installed FFMPEG_jll ─────────────────── v8.0.1+0
#    Installed Xorg_xkeyboard_config_jll ──── v2.44.0+0
#    Installed LLVMOpenMP_jll ─────────────── v18.1.8+0
#    Installed RecipesBase ────────────────── v1.3.4
#    Installed Xorg_libXfixes_jll ─────────── v6.0.2+0
#    Installed FixedPointNumbers ──────────── v0.8.5
#    Installed Qt6Wayland_jll ─────────────── v6.8.2+2
#    Installed LAME_jll ───────────────────── v3.100.3+0
#    Installed GettextRuntime_jll ─────────── v0.22.4+0
#    Installed Libiconv_jll ───────────────── v1.18.0+0
#    Installed Qt6Base_jll ────────────────── v6.8.2+2
#    Installed Xorg_libXrandr_jll ─────────── v1.5.6+0
#    Installed Glib_jll ───────────────────── v2.86.3+0
#    Installed URIs ───────────────────────── v1.6.1
#    Installed Libglvnd_jll ───────────────── v1.7.1+1
#    Installed libvorbis_jll ──────────────── v1.3.8+0
#    Installed Requires ───────────────────── v1.3.1
#    Installed Xorg_libXdmcp_jll ──────────── v1.1.6+0
#    Installed Unzip ──────────────────────── v0.2.0
#    Installed Xorg_libX11_jll ────────────── v1.8.13+0
#   Installing 76 artifacts
#    Installed artifact Xorg_libXau              36.6 KiB
#    Installed artifact LERC                     272.9 KiB
#    Installed artifact Vulkan_Loader            177.3 KiB
#    Installed artifact Xorg_libXcursor          227.1 KiB
#    Installed artifact LAME                     292.5 KiB
#    Installed artifact libpng                   328.7 KiB
#    Installed artifact FreeType2                1.5 MiB
#    Installed artifact libinput                 1.0 MiB
#    Installed artifact JpegTurbo                1.4 MiB
#    Installed artifact HarfBuzz                 1.7 MiB
#    Installed artifact libass                   427.8 KiB
#    Installed artifact LZO                      208.9 KiB
#    Installed artifact Cairo                    2.2 MiB
#    Installed artifact Xorg_libXrandr           97.3 KiB
#    Installed artifact XZ                       1.5 MiB
#    Installed artifact Libffi                   44.2 KiB
#    Installed artifact Xorg_libXinerama         25.5 KiB
#    Installed artifact Xorg_libXdmcp            67.7 KiB
#    Installed artifact libevdev                 117.1 KiB
#    Installed artifact Xorg_libXext             286.6 KiB
#    Installed artifact Xorg_xkbcomp             274.8 KiB
#    Installed artifact Xorg_xcb_util_cursor     27.6 KiB
#    Installed artifact Xorg_libICE              384.9 KiB
#    Installed artifact Graphite2                120.2 KiB
#    Installed artifact Libiconv                 1.9 MiB
#    Installed artifact GettextRuntime           543.0 KiB
#    Installed artifact Opus                     960.9 KiB
#    Installed artifact eudev                    3.9 MiB
#    Installed artifact Xorg_libXi               1.6 MiB
#    Installed artifact libdecor                 44.1 KiB
#    Installed artifact Libtiff                  2.3 MiB
#    Installed artifact libaom                   6.4 MiB
#    Installed artifact x264                     2.1 MiB
#    Installed artifact FFMPEG                   11.7 MiB
#    Installed artifact fzf                      3.3 MiB
#    Installed artifact Xorg_xcb_util            39.5 KiB
#    Installed artifact Pango                    2.0 MiB
#    Installed artifact FriBidi                  78.9 KiB
#    Installed artifact Glib                     7.7 MiB
#    Installed artifact x265                     1.4 MiB
#    Installed artifact Xorg_xcb_util_keysyms    17.8 KiB
#    Installed artifact GLFW                     180.1 KiB
#    Installed artifact Xorg_libxcb              2.1 MiB
#    Installed artifact Libmount                 6.5 MiB
#    Installed artifact Xorg_libxkbfile          91.1 KiB
#    Installed artifact Wayland                  390.6 KiB
#    Installed artifact Expat                    283.3 KiB
#    Installed artifact Xorg_libXfixes           59.0 KiB
#    Installed artifact Qt6ShaderTools           2.1 MiB
#    Installed artifact Ogg                      250.3 KiB
#    Installed artifact Xorg_libSM               164.1 KiB
#    Installed artifact mtdev                    79.6 KiB
#    Installed artifact Xorg_libXrender          435.9 KiB
#    Installed artifact Bzip2                    503.5 KiB
#    Installed artifact GR                       18.7 MiB
#    Installed artifact Qt6Wayland               2.2 MiB
#    Installed artifact libfdk_aac               2.8 MiB
#    Installed artifact Xorg_libX11              4.8 MiB
#    Installed artifact Dbus                     489.8 KiB
#    Installed artifact Xorg_xcb_util_wm         147.9 KiB
#    Installed artifact Xorg_xtrans              48.2 KiB
#    Installed artifact libvorbis                271.0 KiB
#    Installed artifact Xorg_xcb_util_renderutil 32.1 KiB
#    Installed artifact xkbcommon                298.7 KiB
#    Installed artifact Xorg_xcb_util_image      54.3 KiB
#    Installed artifact Fontconfig               984.8 KiB
#    Installed artifact Libuuid                  3.7 MiB
#    Installed artifact Pixman                   372.2 KiB
#    Installed artifact Libglvnd                 833.5 KiB
#    Installed artifact Xorg_xkeyboard_config    537.5 KiB
#    Installed artifact Zstd                     646.0 KiB
#    Installed artifact MbedTLS                  2.2 MiB
#    Installed artifact Qt6Base                  20.6 MiB
#    Installed artifact Qt6Declarative           21.6 MiB
#    Installed artifact LLVMOpenMP               661.6 KiB
#    Installed artifact Ghostscript              31.4 MiB
#     Updating `~/.julia/environments/v1.12/Project.toml`
#   [91a5bcdd] + Plots v1.41.6
#     Updating `~/.julia/environments/v1.12/Manifest.toml`
#   [66dad0bd] + AliasTables v1.1.3
#   [d1d4a3ce] + BitFlags v0.1.9
#   [35d6a980] + ColorSchemes v3.31.0
#   [3da002f7] + ColorTypes v0.12.1
#   [c3611d14] + ColorVectorSpace v0.11.0
#   [5ae59095] + Colors v0.13.1
#   [f0e56b4a] + ConcurrentUtilities v2.5.1
#   [d38c429a] + Contour v0.6.3
#   [8bb1440f] + DelimitedFiles v1.9.1
#   [ffbed154] + DocStringExtensions v0.9.5
#   [460bff9d] + ExceptionUnwrapping v0.1.11
#   [c87230d0] + FFMPEG v0.4.5
#   [53c48c17] + FixedPointNumbers v0.8.5
#   [1fa38f19] + Format v1.3.7
#   [28b8d3ca] + GR v0.73.22
#   [42e2da0e] + Grisu v1.0.2
#   [cd3eb016] + HTTP v1.10.19
#   [92d709cd] + IrrationalConstants v0.2.6
#   [1019f520] + JLFzf v0.1.11
#   [23fbe1c1] + Latexify v0.16.10
#   [2ab3a3ac] + LogExpFunctions v0.3.29
#   [e6f89c97] + LoggingExtras v1.2.0
#   [1914dd2f] + MacroTools v0.5.16
#   [739be429] + MbedTLS v1.1.9
#   [442fdcdd] + Measures v0.3.3
#   [77ba4419] + NaNMath v1.1.3
#   [4d8831e6] + OpenSSL v1.6.1
#   [ccf2f8ad] + PlotThemes v3.3.0
#   [995b91a9] + PlotUtils v1.4.4
#   [91a5bcdd] + Plots v1.41.6
#   [43287f4e] + PtrArrays v1.3.0
#   [3cdcf5f2] + RecipesBase v1.3.4
#   [01d81517] + RecipesPipeline v0.6.12
#   [05181044] + RelocatableFolders v1.0.1
#   [ae029012] + Requires v1.3.1
#   [6c6a2e73] + Scratch v1.3.0
#   [992d4aef] + Showoff v1.0.3
#   [777ac1f9] + SimpleBufferStream v1.2.0
#   [860ef19b] + StableRNGs v1.0.4
#   [82ae8749] + StatsAPI v1.8.0
#   [2913bbd2] + StatsBase v0.34.10
#   [62fd8b95] + TensorCore v0.1.1
#   [5c2747f8] + URIs v1.6.1
#   [1cfade01] + UnicodeFun v0.4.1
#   [41fe7b60] + Unzip v0.2.0
#   [6e34b625] + Bzip2_jll v1.0.9+0
#   [83423d85] + Cairo_jll v1.18.5+1
#   [ee1fde0b] + Dbus_jll v1.16.2+0
#   [2702e6a9] + EpollShim_jll v0.0.20230411+1
#   [2e619515] + Expat_jll v2.7.3+0
#   [b22a6f82] + FFMPEG_jll v8.0.1+0
#   [a3f928ae] + Fontconfig_jll v2.17.1+0
#   [d7e528f0] + FreeType2_jll v2.13.4+0
#   [559328eb] + FriBidi_jll v1.0.17+0
#   [0656b61e] + GLFW_jll v3.4.1+0
#   [d2c73de3] + GR_jll v0.73.22+0
#   [b0724c58] + GettextRuntime_jll v0.22.4+0
#   [61579ee1] + Ghostscript_jll v9.55.1+0
#   [7746bdde] + Glib_jll v2.86.3+0
#   [3b182d85] + Graphite2_jll v1.3.15+0
#   [2e76f6c2] + HarfBuzz_jll v8.5.1+0
#   [aacddb02] + JpegTurbo_jll v3.1.4+0
#   [c1c5ebd0] + LAME_jll v3.100.3+0
#   [88015f11] + LERC_jll v4.0.1+0
#   [1d63c593] + LLVMOpenMP_jll v18.1.8+0
#   [dd4b983a] + LZO_jll v2.10.3+0
# ⌅ [e9f186c6] + Libffi_jll v3.4.7+0
#   [7e76a0d4] + Libglvnd_jll v1.7.1+1
#   [94ce4f54] + Libiconv_jll v1.18.0+0
#   [4b2f31a3] + Libmount_jll v2.41.3+0
#   [89763e89] + Libtiff_jll v4.7.2+0
#   [38a345b3] + Libuuid_jll v2.41.3+0
#   [c8ffd9c3] + MbedTLS_jll v2.28.1010+0
#   [e7412a2a] + Ogg_jll v1.3.6+0
#   [91d4177d] + Opus_jll v1.6.1+0
#   [36c8627f] + Pango_jll v1.57.0+0
# ⌅ [30392449] + Pixman_jll v0.44.2+0
# ⌅ [c0090381] + Qt6Base_jll v6.8.2+2
#   [629bc702] + Qt6Declarative_jll v6.8.2+1
#   [ce943373] + Qt6ShaderTools_jll v6.8.2+1
#   [e99dba38] + Qt6Wayland_jll v6.8.2+2
#   [a44049a8] + Vulkan_Loader_jll v1.3.243+0
#   [a2964d1f] + Wayland_jll v1.24.0+0
#   [ffd25f8a] + XZ_jll v5.8.2+0
#   [f67eecfb] + Xorg_libICE_jll v1.1.2+0
#   [c834827a] + Xorg_libSM_jll v1.2.6+0
#   [4f6342f7] + Xorg_libX11_jll v1.8.13+0
#   [0c0b7dd1] + Xorg_libXau_jll v1.0.13+0
#   [935fb764] + Xorg_libXcursor_jll v1.2.4+0
#   [a3789734] + Xorg_libXdmcp_jll v1.1.6+0
#   [1082639a] + Xorg_libXext_jll v1.3.8+0
#   [d091e8ba] + Xorg_libXfixes_jll v6.0.2+0
#   [a51aa0fd] + Xorg_libXi_jll v1.8.3+0
#   [d1454406] + Xorg_libXinerama_jll v1.1.7+0
#   [ec84b674] + Xorg_libXrandr_jll v1.5.6+0
#   [ea2f1a96] + Xorg_libXrender_jll v0.9.12+0
#   [c7cfdc94] + Xorg_libxcb_jll v1.17.1+0
#   [cc61e674] + Xorg_libxkbfile_jll v1.2.0+0
#   [e920d4aa] + Xorg_xcb_util_cursor_jll v0.1.6+0
#   [12413925] + Xorg_xcb_util_image_jll v0.4.1+0
#   [2def613f] + Xorg_xcb_util_jll v0.4.1+0
#   [975044d2] + Xorg_xcb_util_keysyms_jll v0.4.1+0
#   [0d47668e] + Xorg_xcb_util_renderutil_jll v0.3.10+0
#   [c22f9ab0] + Xorg_xcb_util_wm_jll v0.4.2+0
#   [35661453] + Xorg_xkbcomp_jll v1.4.7+0
#   [33bec58e] + Xorg_xkeyboard_config_jll v2.44.0+0
#   [c5fb5394] + Xorg_xtrans_jll v1.6.0+0
#   [3161d3a3] + Zstd_jll v1.5.7+1
#   [35ca27e7] + eudev_jll v3.2.14+0
#   [214eeab7] + fzf_jll v0.61.1+0
#   [a4ae2306] + libaom_jll v3.13.1+0
#   [0ac62f75] + libass_jll v0.17.4+0
#   [1183f4f0] + libdecor_jll v0.2.2+0
#   [2db6ffa8] + libevdev_jll v1.13.4+0
#   [f638f0a6] + libfdk_aac_jll v2.0.4+0
#   [36db933b] + libinput_jll v1.28.1+0
#   [b53b4c65] + libpng_jll v1.6.55+0
#   [f27f6e37] + libvorbis_jll v1.3.8+0
#   [009596ad] + mtdev_jll v1.1.7+0
# ⌅ [1270edf5] + x264_jll v10164.0.1+0
#   [dfaa095f] + x265_jll v4.1.0+0
#   [d8fb68d0] + xkbcommon_jll v1.13.0+0
#   [9e88b42a] + Serialization v1.11.0
#   [2f01184e] + SparseArrays v1.12.0
#   [8dfed614] + Test v1.11.0
#   [05823500] + OpenLibm_jll v0.8.7+0
#   [efcefdf7] + PCRE2_jll v10.44.0+1
#   [bea87d4a] + SuiteSparse_jll v7.8.3+2
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling packages...
#    1181.0 ms  ✓ StatsAPI
#    1175.7 ms  ✓ StableRNGs
#    1201.3 ms  ✓ Contour
#    1321.7 ms  ✓ Measures
#    1457.6 ms  ✓ TensorCore
#    1635.7 ms  ✓ URIs
#    1835.2 ms  ✓ DocStringExtensions
#    1906.9 ms  ✓ Requires
#     772.3 ms  ✓ SimpleBufferStream
#     939.9 ms  ✓ PtrArrays
#     906.1 ms  ✓ DelimitedFiles
#     920.7 ms  ✓ BitFlags
#    1435.1 ms  ✓ Statistics → SparseArraysExt
#     986.4 ms  ✓ Scratch
#    3215.3 ms  ✓ Format
#    1100.2 ms  ✓ LoggingExtras
#    1830.0 ms  ✓ ConcurrentUtilities
#    1436.7 ms  ✓ ExceptionUnwrapping
#    1372.0 ms  ✓ Graphite2_jll
#    4420.0 ms  ✓ Unzip
#    1370.7 ms  ✓ EpollShim_jll
#    1666.2 ms  ✓ Libmount_jll
#    1455.7 ms  ✓ LLVMOpenMP_jll
#    1394.6 ms  ✓ Bzip2_jll
#    3966.8 ms  ✓ NaNMath
#    5437.1 ms  ✓ Grisu
#    3259.8 ms  ✓ UnicodeFun
#    1571.8 ms  ✓ Xorg_libICE_jll
#    1543.9 ms  ✓ Xorg_libXau_jll
#    1540.6 ms  ✓ libpng_jll
#    6150.2 ms  ✓ IrrationalConstants
#    1543.3 ms  ✓ LERC_jll
#    1652.6 ms  ✓ libfdk_aac_jll
#    1658.7 ms  ✓ LAME_jll
#    1513.2 ms  ✓ fzf_jll
#    1678.2 ms  ✓ JpegTurbo_jll
#    1400.0 ms  ✓ Ogg_jll
#    1394.7 ms  ✓ mtdev_jll
#    1639.9 ms  ✓ XZ_jll
#    1393.1 ms  ✓ Xorg_libXdmcp_jll
#    1396.5 ms  ✓ x265_jll
#    1346.9 ms  ✓ x264_jll
#    1429.9 ms  ✓ Zstd_jll
#    1556.2 ms  ✓ libaom_jll
#    1735.1 ms  ✓ MbedTLS_jll
#    1661.6 ms  ✓ Expat_jll
#    8268.7 ms  ✓ MacroTools
#    1521.3 ms  ✓ Opus_jll
#    1601.3 ms  ✓ LZO_jll
#    1655.1 ms  ✓ Xorg_xtrans_jll
#    1585.6 ms  ✓ libevdev_jll
#    1625.5 ms  ✓ Libiconv_jll
#    1642.9 ms  ✓ Libffi_jll
#    1625.4 ms  ✓ Libuuid_jll
#    1974.6 ms  ✓ eudev_jll
#    1409.4 ms  ✓ AliasTables
#    1371.8 ms  ✓ RelocatableFolders
#    2050.3 ms  ✓ FriBidi_jll
#    1185.0 ms  ✓ Showoff
#    8337.1 ms  ✓ FixedPointNumbers
#    2018.3 ms  ✓ FreeType2_jll
#    2465.4 ms  ✓ Pixman_jll
#    2382.6 ms  ✓ Xorg_libSM_jll
#    2350.9 ms  ✓ LogExpFunctions
#    2472.6 ms  ✓ JLFzf
#    4029.5 ms  ✓ FilePathsBase → FilePathsBaseTestExt
#    2298.7 ms  ✓ Libtiff_jll
#    2530.7 ms  ✓ libvorbis_jll
#    4402.1 ms  ✓ RecipesBase
#    2195.2 ms  ✓ Dbus_jll
#    1929.7 ms  ✓ GettextRuntime_jll
#    1647.2 ms  ✓ libinput_jll
#    3193.3 ms  ✓ MbedTLS
#    5034.8 ms  ✓ OpenSSL
#    3797.7 ms  ✓ Ghostscript_jll
#    2109.9 ms  ✓ Wayland_jll
#    1587.2 ms  ✓ Fontconfig_jll
#    1432.7 ms  ✓ Glib_jll
#    4654.5 ms  ✓ Xorg_libxcb_jll
#     818.2 ms  ✓ Xorg_xcb_util_jll
#     978.5 ms  ✓ Xorg_libX11_jll
#    4267.7 ms  ✓ ColorTypes
#    1258.9 ms  ✓ Xorg_xcb_util_image_jll
#    1268.4 ms  ✓ Xorg_xcb_util_keysyms_jll
#    1278.3 ms  ✓ Xorg_xcb_util_renderutil_jll
#    1284.9 ms  ✓ Xorg_libXrender_jll
#    1292.2 ms  ✓ Xorg_libXext_jll
#    1297.6 ms  ✓ Xorg_libxkbfile_jll
#    1474.7 ms  ✓ Xorg_xcb_util_wm_jll
#    1480.4 ms  ✓ Xorg_libXfixes_jll
#    1028.5 ms  ✓ ColorTypes → StyledStringsExt
#    5758.1 ms  ✓ StatsBase
#    1294.1 ms  ✓ Xorg_libXinerama_jll
#    1536.3 ms  ✓ Xorg_xcb_util_cursor_jll
#    1358.2 ms  ✓ Xorg_libXrandr_jll
#    1353.3 ms  ✓ Xorg_xkbcomp_jll
#    1345.6 ms  ✓ Xorg_libXcursor_jll
#    1734.1 ms  ✓ Cairo_jll
#    1927.8 ms  ✓ Libglvnd_jll
#    1473.0 ms  ✓ Xorg_libXi_jll
#    1021.2 ms  ✓ Xorg_xkeyboard_config_jll
#    1284.7 ms  ✓ HarfBuzz_jll
#    1224.7 ms  ✓ xkbcommon_jll
#    7218.3 ms  ✓ Latexify
#    1262.3 ms  ✓ libass_jll
#    1420.8 ms  ✓ Pango_jll
#    1142.1 ms  ✓ Vulkan_Loader_jll
#    1304.5 ms  ✓ Latexify → SparseArraysExt
#    5806.0 ms  ✓ ColorVectorSpace
#    1200.7 ms  ✓ libdecor_jll
#    1937.4 ms  ✓ FFMPEG_jll
#    2346.5 ms  ✓ Latexify → DataFramesExt
#    1095.8 ms  ✓ GLFW_jll
#    2067.7 ms  ✓ Qt6Base_jll
#     693.2 ms  ✓ FFMPEG
#    1010.5 ms  ✓ Qt6ShaderTools_jll
#    8091.8 ms  ✓ Colors
#    1435.4 ms  ✓ GR_jll
#    3367.3 ms  ✓ Qt6Declarative_jll
#     843.1 ms  ✓ Qt6Wayland_jll
#    4378.1 ms  ✓ ColorSchemes
#   22589.0 ms  ✓ HTTP
#   11178.5 ms  ✓ PlotUtils
#    5948.6 ms  ✓ GR
#    1330.2 ms  ✓ GR → IJuliaExt
#    3272.9 ms  ✓ PlotThemes
#    4374.7 ms  ✓ RecipesPipeline
#   56787.1 ms  ✓ Plots
#    2752.1 ms  ✓ Plots → IJuliaExt
#   129 dependencies successfully precompiled in 106 seconds. 80 already precompiled.

# %%
using Plots

# %%
Pkg.add("Interpolations")
# Out:
#    Resolving package versions...
#    Installed StaticArraysCore ─ v1.4.4
#    Installed AxisAlgorithms ─── v1.1.0
#    Installed Ratios ─────────── v0.4.5
#    Installed Adapt ──────────── v4.4.0
#    Installed OffsetArrays ───── v1.17.0
#    Installed StaticArrays ───── v1.9.17
#    Installed ChainRulesCore ─── v1.26.0
#    Installed Interpolations ─── v0.16.2
#    Installed WoodburyMatrices ─ v1.1.0
#     Updating `~/.julia/environments/v1.12/Project.toml`
#   [a98d9a8b] + Interpolations v0.16.2
#     Updating `~/.julia/environments/v1.12/Manifest.toml`
#   [79e6a3ab] + Adapt v4.4.0
#   [13072b0f] + AxisAlgorithms v1.1.0
#   [d360d2e6] + ChainRulesCore v1.26.0
#   [a98d9a8b] + Interpolations v0.16.2
#   [6fe1bfb0] + OffsetArrays v1.17.0
#   [c84ed2f1] + Ratios v0.4.5
#   [90137ffa] + StaticArrays v1.9.17
#   [1e83bf80] + StaticArraysCore v1.4.4
#   [efce3f68] + WoodburyMatrices v1.1.0
#   [8ba89e20] + Distributed v1.11.0
#   [1a1011a3] + SharedArrays v1.11.0
# Precompiling packages...
#     495.9 ms  ✓ Ratios
#     576.0 ms  ✓ StaticArraysCore
#     582.4 ms  ✓ Adapt
#     768.8 ms  ✓ WoodburyMatrices
#     519.8 ms  ✓ Ratios → RatiosFixedPointNumbersExt
#    1164.4 ms  ✓ OffsetArrays
#     701.6 ms  ✓ Adapt → AdaptSparseArraysExt
#     753.2 ms  ✓ AxisAlgorithms
#     495.4 ms  ✓ OffsetArrays → OffsetArraysAdaptExt
#    2700.3 ms  ✓ ChainRulesCore
#    1542.0 ms  ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#    1820.7 ms  ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#    8219.0 ms  ✓ StaticArrays
#     567.4 ms  ✓ Adapt → AdaptStaticArraysExt
#     634.9 ms  ✓ StaticArrays → StaticArraysStatisticsExt
#    1700.3 ms  ✓ StaticArrays → StaticArraysChainRulesCoreExt
#    2576.7 ms  ✓ Interpolations
#   17 dependencies successfully precompiled in 13 seconds. 211 already precompiled.

# %%
using Interpolations

# %%
Pkg.add("Polynomials")
# Out:
#    Resolving package versions...
#    Installed ConstructionBase ─ v1.6.0
#    Installed Polynomials ────── v4.1.0
#    Installed Setfield ───────── v1.1.2
#     Updating `~/.julia/environments/v1.12/Project.toml`
#   [f27b6e38] + Polynomials v4.1.0
#     Updating `~/.julia/environments/v1.12/Manifest.toml`
#   [187b0558] + ConstructionBase v1.6.0
#   [f27b6e38] + Polynomials v4.1.0
#   [efcf1570] + Setfield v1.1.2
# Precompiling packages...
#    1550.4 ms  ✓ ConstructionBase
#     400.9 ms  ✓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#     561.6 ms  ✓ ConstructionBase → ConstructionBaseStaticArraysExt
#    1051.6 ms  ✓ Setfield
#   20152.2 ms  ✓ Polynomials
#     929.5 ms  ✓ Polynomials → PolynomialsChainRulesCoreExt
#   6 dependencies successfully precompiled in 24 seconds. 228 already precompiled.

# %%
using Polynomials

# %%
Pkg.add("TaylorSeries")
# Out:
#    Resolving package versions...
#    Installed TaylorSeries ─ v0.20.10
#     Updating `~/.julia/environments/v1.12/Project.toml`
#   [6aa5eb33] + TaylorSeries v0.20.10
#     Updating `~/.julia/environments/v1.12/Manifest.toml`
#   [6aa5eb33] + TaylorSeries v0.20.10
# Precompiling packages...
#    4228.8 ms  ✓ TaylorSeries
#     896.8 ms  ✓ TaylorSeries → TaylorSeriesSAExt
#   2 dependencies successfully precompiled in 6 seconds. 234 already precompiled.

# %%
using TaylorSeries

# %%
Pkg.add("SpecialPolynomials")
# Out:
#    Resolving package versions...
#    Installed HypergeometricFunctions ─ v0.3.28
#    Installed Memoize ───────────────── v0.4.4
#    Installed OpenSpecFun_jll ───────── v0.5.6+0
#    Installed SpecialFunctions ──────── v2.7.1
#    Installed QuadGK ────────────────── v2.11.2
#    Installed SpecialPolynomials ────── v0.5.0
#   Installing 1 artifacts
#    Installed artifact OpenSpecFun              194.9 KiB
#     Updating `~/.julia/environments/v1.12/Project.toml`
#   [a25cea48] + SpecialPolynomials v0.5.0
#     Updating `~/.julia/environments/v1.12/Manifest.toml`
#   [34004b35] + HypergeometricFunctions v0.3.28
#   [c03570c3] + Memoize v0.4.4
#   [1fd47b50] + QuadGK v2.11.2
#   [276daf66] + SpecialFunctions v2.7.1
#   [a25cea48] + SpecialPolynomials v0.5.0
#   [efe28fd5] + OpenSpecFun_jll v0.5.6+0
# Precompiling packages...
#     392.1 ms  ✓ Memoize
#     689.0 ms  ✓ OpenSpecFun_jll
#    2096.8 ms  ✓ QuadGK
#    2622.9 ms  ✓ SpecialFunctions
#     548.1 ms  ✓ ColorVectorSpace → SpecialFunctionsExt
#     999.5 ms  ✓ HypergeometricFunctions
#    1742.7 ms  ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#    3077.4 ms  ✓ SpecialPolynomials
#   8 dependencies successfully precompiled in 8 seconds. 236 already precompiled.

# %%
using SpecialPolynomials

# %%
Pkg.add("QuadGK")
# Out:
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.12/Project.toml`
#   [1fd47b50] + QuadGK v2.11.2
#     Manifest No packages added to or removed from `~/.julia/environments/v1.12/Manifest.toml`

# %%
using QuadGK

# %%
Pkg.add("FFTW")
# Out:
#    Resolving package versions...
#    Installed IntelOpenMP_jll ─ v2025.2.0+0
#    Installed MKL_jll ───────── v2025.2.0+0
#    Installed FFTW_jll ──────── v3.3.11+0
#    Installed oneTBB_jll ────── v2022.0.0+1
#    Installed FFTW ──────────── v1.10.0
#    Installed AbstractFFTs ──── v1.5.0
#   Installing 1 artifacts
#    Installed artifact FFTW                     2.2 MiB
#     Updating `~/.julia/environments/v1.12/Project.toml`
#   [7a1cc6ca] + FFTW v1.10.0
#     Updating `~/.julia/environments/v1.12/Manifest.toml`
#   [621f4979] + AbstractFFTs v1.5.0
#   [7a1cc6ca] + FFTW v1.10.0
#   [f5851436] + FFTW_jll v3.3.11+0
#   [1d5cc7b8] + IntelOpenMP_jll v2025.2.0+0
#   [856f044c] + MKL_jll v2025.2.0+0
#   [1317d2d5] + oneTBB_jll v2022.0.0+1
#   [4af54fe1] + LazyArtifacts v1.11.0
# Precompiling packages...
#     599.7 ms  ✓ AbstractFFTs
#     803.8 ms  ✓ FFTW_jll
#     523.9 ms  ✓ AbstractFFTs → AbstractFFTsChainRulesCoreExt
#    1288.0 ms  ✓ IntelOpenMP_jll
#    1442.9 ms  ✓ oneTBB_jll
#    1523.3 ms  ✓ AbstractFFTs → AbstractFFTsTestExt
#    8884.2 ms  ✓ MKL_jll
#    7619.3 ms  ✓ FFTW
#     925.3 ms  ✓ Polynomials → PolynomialsFFTWExt
#   9 dependencies successfully precompiled in 19 seconds. 245 already precompiled.
#   1 dependency had output during precompilation:
# ┌ MKL_jll
# │   Downloading artifact: IntelOpenMP
# │   Downloading artifact: oneTBB
# └

# %%
using FFTW

# %%
Pkg.add("DifferentialEquations")
# Out:
#    Resolving package versions...
#    Installed OrdinaryDiffEqRosenbrock ──────────── v1.23.0
#    Installed SciMLPublic ───────────────────────── v1.0.1
#    Installed StatsFuns ─────────────────────────── v1.5.2
#    Installed OrdinaryDiffEqRKN ─────────────────── v1.9.0
#    Installed Accessors ─────────────────────────── v0.1.43
#    Installed DifferentialEquations ─────────────── v7.17.0
#    Installed OrdinaryDiffEqStabilizedRK ────────── v1.8.0
#    Installed AlmostBlockDiagonals ──────────────── v0.1.10
#    Installed OrdinaryDiffEqSDIRK ───────────────── v1.12.0
#    Installed FastGaussQuadrature ───────────────── v1.1.0
#    Installed NonlinearSolve ────────────────────── v4.16.0
#    Installed BoundaryValueDiffEqFIRK ───────────── v1.11.0
#    Installed SciMLLogging ──────────────────────── v1.9.1
#    Installed TimerOutputs ──────────────────────── v0.5.29
#    Installed PDMats ────────────────────────────── v0.11.37
#    Installed SciMLJacobianOperators ────────────── v0.1.12
#    Installed EnumX ─────────────────────────────── v1.0.6
#    Installed Polyester ─────────────────────────── v0.7.19
#    Installed OrdinaryDiffEqPRK ─────────────────── v1.8.0
#    Installed Sundials_jll ──────────────────────── v7.5.0+0
#    Installed BoundaryValueDiffEqMIRK ───────────── v1.11.0
#    Installed RecursiveArrayTools ───────────────── v3.48.0
#    Installed Integrals ─────────────────────────── v5.1.0
#    Installed MaybeInplace ──────────────────────── v0.1.4
#    Installed CEnum ─────────────────────────────── v0.5.0
#    Installed OpenBLAS32_jll ────────────────────── v0.3.30+0
#    Installed FunctionWrappers ──────────────────── v1.1.3
#    Installed OrdinaryDiffEqAdamsBashforthMoulton ─ v1.9.0
#    Installed OrdinaryDiffEqCore ────────────────── v3.5.2
#    Installed OrdinaryDiffEqSSPRK ───────────────── v1.11.0
#    Installed Static ────────────────────────────── v1.3.1
#    Installed OrdinaryDiffEqVerner ──────────────── v1.11.0
#    Installed MuladdMacro ───────────────────────── v0.2.4
#    Installed FiniteDiff ────────────────────────── v2.29.0
#    Installed SIMDTypes ─────────────────────────── v0.1.0
#    Installed FastPower ─────────────────────────── v1.3.1
#    Installed BoundaryValueDiffEq ───────────────── v5.20.0
#    Installed SteadyStateDiffEq ─────────────────── v2.9.0
#    Installed BoundaryValueDiffEqCore ───────────── v2.0.0
#    Installed ArnoldiMethod ─────────────────────── v0.4.0
#    Installed DiffEqBase ────────────────────────── v6.205.1
#    Installed SciMLBase ─────────────────────────── v2.140.0
#    Installed BandedMatrices ────────────────────── v1.11.0
#    Installed CpuId ─────────────────────────────── v0.3.1
#    Installed OrdinaryDiffEqFIRK ────────────────── v1.22.0
#    Installed Sobol ─────────────────────────────── v1.5.0
#    Installed OrdinaryDiffEqNonlinearSolve ──────── v1.20.0
#    Installed NonlinearSolveQuasiNewton ─────────── v1.12.0
#    Installed ADTypes ───────────────────────────── v1.21.0
#    Installed BoundaryValueDiffEqMIRKN ──────────── v1.10.0
#    Installed BracketingNonlinearSolve ──────────── v1.10.0
#    Installed IfElse ────────────────────────────── v0.1.1
#    Installed SimpleNonlinearSolve ──────────────── v2.11.0
#    Installed LineSearch ────────────────────────── v0.1.6
#    Installed DiffEqNoiseProcess ────────────────── v5.27.0
#    Installed LinearSolve ───────────────────────── v3.59.1
#    Installed NonlinearSolveSpectralMethods ─────── v1.6.0
#    Installed ThreadingUtilities ────────────────── v0.5.5
#    Installed MonteCarloIntegration ─────────────── v0.2.0
#    Installed SparseConnectivityTracer ──────────── v1.2.1
#    Installed SparseMatrixColorings ─────────────── v0.4.23
#    Installed Graphs ────────────────────────────── v1.13.4
#    Installed JumpProcesses ─────────────────────── v9.22.0
#    Installed OrdinaryDiffEq ────────────────────── v6.108.0
#    Installed ManualMemory ──────────────────────── v0.1.8
#    Installed NLSolversBase ─────────────────────── v8.0.0
#    Installed Rmath_jll ─────────────────────────── v0.5.1+0
#    Installed LevyArea ──────────────────────────── v1.0.0
#    Installed CommonSubexpressions ──────────────── v0.3.1
#    Installed FastAlmostBandedMatrices ──────────── v0.1.6
#    Installed LazyArrays ────────────────────────── v2.9.5
#    Installed ExprTools ─────────────────────────── v0.1.10
#    Installed CommonWorldInvalidations ──────────── v1.0.0
#    Installed StaticArrayInterface ──────────────── v1.9.0
#    Installed ArrayLayouts ──────────────────────── v1.12.2
#    Installed MatrixFactorizations ──────────────── v3.1.3
#    Installed OrdinaryDiffEqLinear ──────────────── v1.10.0
#    Installed DiffRules ─────────────────────────── v1.15.1
#    Installed BitTwiddlingConvenienceFunctions ──── v0.1.6
#    Installed SciMLStructures ───────────────────── v1.10.0
#    Installed OrdinaryDiffEqExplicitRK ──────────── v1.9.0
#    Installed GenericSchur ──────────────────────── v0.5.6
#    Installed FunctionWrappersWrappers ──────────── v0.1.3
#    Installed OrdinaryDiffEqPDIRK ───────────────── v1.11.0
#    Installed LayoutPointers ────────────────────── v0.1.17
#    Installed Sundials ──────────────────────────── v5.1.0
#    Installed HCubature ─────────────────────────── v1.8.0
#    Installed LatticeRules ──────────────────────── v0.0.1
#    Installed OrdinaryDiffEqQPRK ────────────────── v1.8.0
#    Installed StochasticDiffEq ──────────────────── v6.94.0
#    Installed QuasiMonteCarlo ───────────────────── v0.3.5
#    Installed DiffResults ───────────────────────── v1.1.0
#    Installed OrdinaryDiffEqLowOrderRK ──────────── v1.10.0
#    Installed Inflate ───────────────────────────── v0.1.5
#    Installed OrdinaryDiffEqFunctionMap ─────────── v1.9.0
#    Installed NonlinearSolveBase ────────────────── v2.11.2
#    Installed ExproniconLite ────────────────────── v0.10.14
#    Installed DiffEqCallbacks ───────────────────── v4.12.0
#    Installed SciMLOperators ────────────────────── v1.15.1
#    Installed DelayDiffEq ───────────────────────── v5.68.0
#    Installed EnzymeCore ────────────────────────── v0.8.18
#    Installed FastClosures ──────────────────────── v0.3.2
#    Installed Combinatorics ─────────────────────── v1.1.0
#    Installed OrdinaryDiffEqExponentialRK ───────── v1.13.0
#    Installed PolyesterWeave ────────────────────── v0.2.2
#    Installed NonlinearSolveFirstOrder ──────────── v2.0.0
#    Installed ArrayInterface ────────────────────── v7.22.0
#    Installed BoundaryValueDiffEqShooting ───────── v1.11.0
#    Installed LineSearches ──────────────────────── v7.6.0
#    Installed OrdinaryDiffEqTsit5 ───────────────── v1.9.0
#    Installed PreallocationTools ────────────────── v0.4.34
#    Installed OrdinaryDiffEqExtrapolation ───────── v1.15.0
#    Installed SuiteSparse32_jll ─────────────────── v7.12.1+0
#    Installed CloseOpenIntervals ────────────────── v0.1.13
#    Installed OrdinaryDiffEqLowStorageRK ────────── v1.12.0
#    Installed CompositionsBase ──────────────────── v0.1.2
#    Installed InverseFunctions ──────────────────── v0.1.17
#    Installed CommonSolve ───────────────────────── v0.2.6
#    Installed OrdinaryDiffEqStabilizedIRK ───────── v1.11.0
#    Installed SimpleTraits ──────────────────────── v0.9.5
#    Installed GPUArraysCore ─────────────────────── v0.2.0
#    Installed OrdinaryDiffEqBDF ─────────────────── v1.17.0
#    Installed Rmath ─────────────────────────────── v0.9.0
#    Installed ExponentialUtilities ──────────────── v1.30.0
#    Installed StrideArraysCore ──────────────────── v0.5.8
#    Installed OrdinaryDiffEqDifferentiation ─────── v2.0.0
#    Installed IntegerMathUtils ──────────────────── v0.1.3
#    Installed DifferentiationInterface ──────────── v0.7.16
#    Installed OrdinaryDiffEqHighOrderRK ─────────── v1.9.0
#    Installed Krylov ────────────────────────────── v0.10.5
#    Installed RuntimeGeneratedFunctions ─────────── v0.5.17
#    Installed Moshi ─────────────────────────────── v0.3.7
#    Installed CPUSummary ────────────────────────── v0.2.7
#    Installed Jieko ─────────────────────────────── v0.2.1
#    Installed Primes ────────────────────────────── v0.5.7
#    Installed OrdinaryDiffEqFeagin ──────────────── v1.8.0
#    Installed ConcreteStructs ───────────────────── v0.2.3
#    Installed PoissonRandom ─────────────────────── v0.4.7
#    Installed FillArrays ────────────────────────── v1.16.0
#    Installed SymbolicIndexingInterface ─────────── v0.3.46
#    Installed ForwardDiff ───────────────────────── v1.3.2
#    Installed ResettableStacks ──────────────────── v1.2.0
#    Installed TruncatedStacktraces ──────────────── v1.4.0
#    Installed BoundaryValueDiffEqAscher ─────────── v1.10.0
#    Installed OrdinaryDiffEqSymplecticRK ────────── v1.11.0
#    Installed FastBroadcast ─────────────────────── v0.3.5
#    Installed OrdinaryDiffEqDefault ─────────────── v1.12.0
#    Installed OrdinaryDiffEqIMEXMultistep ───────── v1.12.0
#    Installed OptimizationBase ──────────────────── v5.0.0
#    Installed OrdinaryDiffEqNordsieck ───────────── v1.9.0
#    Installed Distributions ─────────────────────── v0.25.123
#   Installing 4 artifacts
#    Installed artifact Rmath                    121.9 KiB
#    Installed artifact SuiteSparse32            1.7 MiB
#    Installed artifact Sundials                 2.2 MiB
#    Installed artifact OpenBLAS32               10.0 MiB
#     Updating `~/.julia/environments/v1.12/Project.toml`
#   [0c46a032] + DifferentialEquations v7.17.0
#     Updating `~/.julia/environments/v1.12/Manifest.toml`
#   [47edcb42] + ADTypes v1.21.0
#   [7d9f7c33] + Accessors v0.1.43
#   [a95523ee] + AlmostBlockDiagonals v0.1.10
#   [ec485272] + ArnoldiMethod v0.4.0
#   [4fba245c] + ArrayInterface v7.22.0
#   [4c555306] + ArrayLayouts v1.12.2
#   [aae01518] + BandedMatrices v1.11.0
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.6
#   [764a87c0] + BoundaryValueDiffEq v5.20.0
#   [7227322d] + BoundaryValueDiffEqAscher v1.10.0
#   [56b672f2] + BoundaryValueDiffEqCore v2.0.0
#   [85d9eb09] + BoundaryValueDiffEqFIRK v1.11.0
#   [1a22d4ce] + BoundaryValueDiffEqMIRK v1.11.0
#   [9255f1d6] + BoundaryValueDiffEqMIRKN v1.10.0
#   [ed55bfe0] + BoundaryValueDiffEqShooting v1.11.0
#   [70df07ce] + BracketingNonlinearSolve v1.10.0
#   [fa961155] + CEnum v0.5.0
#   [2a0fbf3d] + CPUSummary v0.2.7
#   [fb6a15b2] + CloseOpenIntervals v0.1.13
#   [861a8166] + Combinatorics v1.1.0
#   [38540f10] + CommonSolve v0.2.6
#   [bbf7d656] + CommonSubexpressions v0.3.1
#   [f70d9fcc] + CommonWorldInvalidations v1.0.0
#   [a33af91c] + CompositionsBase v0.1.2
#   [2569d6c7] + ConcreteStructs v0.2.3
#   [adafc99b] + CpuId v0.3.1
#   [bcd4f6db] + DelayDiffEq v5.68.0
#   [2b5f629d] + DiffEqBase v6.205.1
#   [459566f4] + DiffEqCallbacks v4.12.0
#   [77a26b50] + DiffEqNoiseProcess v5.27.0
#   [163ba53b] + DiffResults v1.1.0
#   [b552c78f] + DiffRules v1.15.1
#   [0c46a032] + DifferentialEquations v7.17.0
#   [a0c0ee7d] + DifferentiationInterface v0.7.16
#   [31c24e10] + Distributions v0.25.123
#   [4e289a0a] + EnumX v1.0.6
#   [f151be2c] + EnzymeCore v0.8.18
#   [d4d017d3] + ExponentialUtilities v1.30.0
#   [e2ba6199] + ExprTools v0.1.10
#   [55351af7] + ExproniconLite v0.10.14
#   [9d29842c] + FastAlmostBandedMatrices v0.1.6
#   [7034ab61] + FastBroadcast v0.3.5
#   [9aa1b823] + FastClosures v0.3.2
#   [442a2c76] + FastGaussQuadrature v1.1.0
#   [a4df4552] + FastPower v1.3.1
#   [1a297f60] + FillArrays v1.16.0
#   [6a86dc24] + FiniteDiff v2.29.0
#   [f6369f11] + ForwardDiff v1.3.2
#   [069b7b12] + FunctionWrappers v1.1.3
#   [77dc65aa] + FunctionWrappersWrappers v0.1.3
#   [46192b85] + GPUArraysCore v0.2.0
#   [c145ed77] + GenericSchur v0.5.6
#   [86223c79] + Graphs v1.13.4
#   [19dc6840] + HCubature v1.8.0
#   [615f187c] + IfElse v0.1.1
#   [d25df0c9] + Inflate v0.1.5
#   [18e54dd8] + IntegerMathUtils v0.1.3
#   [de52edbc] + Integrals v5.1.0
#   [3587e190] + InverseFunctions v0.1.17
#   [ae98c720] + Jieko v0.2.1
#   [ccbc3e58] + JumpProcesses v9.22.0
#   [ba0b0d4f] + Krylov v0.10.5
#   [73f95e8e] + LatticeRules v0.0.1
#   [10f19ff3] + LayoutPointers v0.1.17
#   [5078a376] + LazyArrays v2.9.5
#   [2d8b4e74] + LevyArea v1.0.0
#   [87fe0de2] + LineSearch v0.1.6
#   [d3d80556] + LineSearches v7.6.0
#   [7ed4a6bd] + LinearSolve v3.59.1
#   [d125e4d3] + ManualMemory v0.1.8
#   [a3b82374] + MatrixFactorizations v3.1.3
#   [bb5d69b7] + MaybeInplace v0.1.4
#   [4886b29c] + MonteCarloIntegration v0.2.0
#   [2e0e35c7] + Moshi v0.3.7
#   [46d2c3a1] + MuladdMacro v0.2.4
#   [d41bc354] + NLSolversBase v8.0.0
#   [8913a72c] + NonlinearSolve v4.16.0
# ⌃ [be0214bd] + NonlinearSolveBase v2.11.2
#   [5959db7a] + NonlinearSolveFirstOrder v2.0.0
#   [9a2c21bd] + NonlinearSolveQuasiNewton v1.12.0
#   [26075421] + NonlinearSolveSpectralMethods v1.6.0
#   [bca83a33] + OptimizationBase v5.0.0
#   [1dea7af3] + OrdinaryDiffEq v6.108.0
#   [89bda076] + OrdinaryDiffEqAdamsBashforthMoulton v1.9.0
#   [6ad6398a] + OrdinaryDiffEqBDF v1.17.0
#   [bbf590c4] + OrdinaryDiffEqCore v3.5.2
#   [50262376] + OrdinaryDiffEqDefault v1.12.0
#   [4302a76b] + OrdinaryDiffEqDifferentiation v2.0.0
#   [9286f039] + OrdinaryDiffEqExplicitRK v1.9.0
#   [e0540318] + OrdinaryDiffEqExponentialRK v1.13.0
#   [becaefa8] + OrdinaryDiffEqExtrapolation v1.15.0
#   [5960d6e9] + OrdinaryDiffEqFIRK v1.22.0
#   [101fe9f7] + OrdinaryDiffEqFeagin v1.8.0
#   [d3585ca7] + OrdinaryDiffEqFunctionMap v1.9.0
#   [d28bc4f8] + OrdinaryDiffEqHighOrderRK v1.9.0
#   [9f002381] + OrdinaryDiffEqIMEXMultistep v1.12.0
#   [521117fe] + OrdinaryDiffEqLinear v1.10.0
#   [1344f307] + OrdinaryDiffEqLowOrderRK v1.10.0
#   [b0944070] + OrdinaryDiffEqLowStorageRK v1.12.0
#   [127b3ac7] + OrdinaryDiffEqNonlinearSolve v1.20.0
#   [c9986a66] + OrdinaryDiffEqNordsieck v1.9.0
#   [5dd0a6cf] + OrdinaryDiffEqPDIRK v1.11.0
#   [5b33eab2] + OrdinaryDiffEqPRK v1.8.0
#   [04162be5] + OrdinaryDiffEqQPRK v1.8.0
#   [af6ede74] + OrdinaryDiffEqRKN v1.9.0
#   [43230ef6] + OrdinaryDiffEqRosenbrock v1.23.0
#   [2d112036] + OrdinaryDiffEqSDIRK v1.12.0
#   [669c94d9] + OrdinaryDiffEqSSPRK v1.11.0
#   [e3e12d00] + OrdinaryDiffEqStabilizedIRK v1.11.0
#   [358294b1] + OrdinaryDiffEqStabilizedRK v1.8.0
#   [fa646aed] + OrdinaryDiffEqSymplecticRK v1.11.0
#   [b1df2697] + OrdinaryDiffEqTsit5 v1.9.0
#   [79d7bb75] + OrdinaryDiffEqVerner v1.11.0
#   [90014a1f] + PDMats v0.11.37
#   [e409e4f3] + PoissonRandom v0.4.7
#   [f517fe37] + Polyester v0.7.19
#   [1d0040c9] + PolyesterWeave v0.2.2
# ⌅ [d236fae5] + PreallocationTools v0.4.34
#   [27ebfcd6] + Primes v0.5.7
#   [8a4e6c94] + QuasiMonteCarlo v0.3.5
#   [731186ca] + RecursiveArrayTools v3.48.0
#   [ae5879a3] + ResettableStacks v1.2.0
#   [79098fc4] + Rmath v0.9.0
#   [7e49a35a] + RuntimeGeneratedFunctions v0.5.17
#   [94e857df] + SIMDTypes v0.1.0
#   [0bca4576] + SciMLBase v2.140.0
#   [19f34311] + SciMLJacobianOperators v0.1.12
#   [a6db7da4] + SciMLLogging v1.9.1
#   [c0aeaf25] + SciMLOperators v1.15.1
#   [431bcebd] + SciMLPublic v1.0.1
#   [53ae85a6] + SciMLStructures v1.10.0
#   [727e6d20] + SimpleNonlinearSolve v2.11.0
#   [699a6c99] + SimpleTraits v0.9.5
#   [ed01d8cd] + Sobol v1.5.0
#   [9f842d2f] + SparseConnectivityTracer v1.2.1
#   [0a514795] + SparseMatrixColorings v0.4.23
#   [aedffcd0] + Static v1.3.1
#   [0d7ed370] + StaticArrayInterface v1.9.0
#   [4c63d2b9] + StatsFuns v1.5.2
#   [9672c7b4] + SteadyStateDiffEq v2.9.0
#   [789caeaf] + StochasticDiffEq v6.94.0
#   [7792a7ef] + StrideArraysCore v0.5.8
#   [c3572dad] + Sundials v5.1.0
#   [2efcf032] + SymbolicIndexingInterface v0.3.46
#   [8290d209] + ThreadingUtilities v0.5.5
#   [a759f4b9] + TimerOutputs v0.5.29
#   [781d530d] + TruncatedStacktraces v1.4.0
#   [656ef2d0] + OpenBLAS32_jll v0.3.30+0
#   [f50d1b31] + Rmath_jll v0.5.1+0
#   [ca45d3f4] + SuiteSparse32_jll v7.12.1+0
#   [fb77eaff] + Sundials_jll v7.5.0+0
#   [4607b0f0] + SuiteSparse
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling packages...
#     939.8 ms  ✓ ConcreteStructs
#     985.3 ms  ✓ ExprTools
#     979.8 ms  ✓ CommonSolve
#    1050.3 ms  ✓ InverseFunctions
#    1170.8 ms  ✓ ManualMemory
#    1281.7 ms  ✓ EnumX
#    1318.6 ms  ✓ SciMLPublic
#    1391.7 ms  ✓ IntegerMathUtils
#    1484.3 ms  ✓ LatticeRules
#    1604.3 ms  ✓ ADTypes
#    1087.5 ms  ✓ Inflate
#    1021.8 ms  ✓ CommonWorldInvalidations
#    1119.0 ms  ✓ IfElse
#     931.0 ms  ✓ MuladdMacro
#    1096.0 ms  ✓ FastClosures
#     860.8 ms  ✓ SIMDTypes
#     836.2 ms  ✓ CompositionsBase
#    2542.0 ms  ✓ Combinatorics
#     782.8 ms  ✓ FastPower
#     854.5 ms  ✓ DiffResults
#    1038.5 ms  ✓ CommonSubexpressions
#    1296.4 ms  ✓ EnzymeCore
#    2129.2 ms  ✓ FillArrays
#    1175.7 ms  ✓ PoissonRandom
#    2335.2 ms  ✓ GenericSchur
#    1525.2 ms  ✓ CpuId
#    1248.2 ms  ✓ GPUArraysCore
#    1115.5 ms  ✓ SciMLLogging
#    1571.1 ms  ✓ SimpleTraits
#    4776.4 ms  ✓ FunctionWrappers
#    1203.6 ms  ✓ TruncatedStacktraces
#    3517.7 ms  ✓ CEnum
#    2387.7 ms  ✓ Sobol
#    1482.8 ms  ✓ OpenBLAS32_jll
#    1419.3 ms  ✓ Rmath_jll
#    1980.3 ms  ✓ PDMats
#    1196.3 ms  ✓ DiffRules
#    1281.8 ms  ✓ ResettableStacks
#    1246.4 ms  ✓ LevyArea
#     963.1 ms  ✓ InverseFunctions → InverseFunctionsDatesExt
#    6538.7 ms  ✓ ExproniconLite
#    2666.5 ms  ✓ SuiteSparse32_jll
#    3802.8 ms  ✓ ArrayInterface
#     932.4 ms  ✓ LogExpFunctions → LogExpFunctionsInverseFunctionsExt
#    1311.5 ms  ✓ InverseFunctions → InverseFunctionsTestExt
#     972.9 ms  ✓ ADTypes → ADTypesChainRulesCoreExt
#    1269.5 ms  ✓ Primes
#    2933.3 ms  ✓ FastGaussQuadrature
#     848.8 ms  ✓ ADTypes → ADTypesConstructionBaseExt
#     882.5 ms  ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#    1011.9 ms  ✓ EnzymeCore → AdaptExt
#    1186.2 ms  ✓ EnzymeCore → EnzymeCoreChainRulesCoreExt
#    3812.7 ms  ✓ RuntimeGeneratedFunctions
#    4312.0 ms  ✓ AlmostBlockDiagonals
#     957.9 ms  ✓ ADTypes → ADTypesEnzymeCoreExt
#     855.5 ms  ✓ FillArrays → FillArraysStatisticsExt
#    5395.2 ms  ✓ ArnoldiMethod
#     839.2 ms  ✓ FunctionWrappersWrappers
#    1292.7 ms  ✓ FillArrays → FillArraysStaticArraysExt
#    1448.8 ms  ✓ FillArrays → FillArraysSparseArraysExt
#    1582.6 ms  ✓ Rmath
#    4941.9 ms  ✓ ThreadingUtilities
#    1464.7 ms  ✓ PDMats → StatsBaseExt
#    1354.5 ms  ✓ FillArrays → FillArraysPDMatsExt
#    4873.9 ms  ✓ DifferentiationInterface
#     983.9 ms  ✓ ArrayInterface → ArrayInterfaceChainRulesCoreExt
#    1428.4 ms  ✓ MaybeInplace
#     853.7 ms  ✓ ArrayInterface → ArrayInterfaceGPUArraysCoreExt
#    1444.7 ms  ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#    1175.6 ms  ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#    8478.8 ms  ✓ TimerOutputs
#    4030.7 ms  ✓ Jieko
#    2503.0 ms  ✓ PreallocationTools
#    5014.3 ms  ✓ Sundials_jll
#    4847.2 ms  ✓ SciMLStructures
#    8997.6 ms  ✓ HCubature
#    1128.6 ms  ✓ DifferentiationInterface → DifferentiationInterfaceGPUArraysCoreExt
#   15260.0 ms  ✓ Krylov
#    1381.2 ms  ✓ DifferentiationInterface → DifferentiationInterfaceStaticArraysExt
#    1012.3 ms  ✓ DifferentiationInterface → DifferentiationInterfaceChainRulesCoreExt
#    1374.9 ms  ✓ DifferentiationInterface → DifferentiationInterfaceSparseArraysExt
#    5924.0 ms  ✓ SpecialPolynomials → SpecialPolynomialsFastGaussQuadratureExt
#    1399.0 ms  ✓ MaybeInplace → MaybeInplaceSparseArraysExt
#    1439.8 ms  ✓ FiniteDiff
#    1078.1 ms  ✓ DifferentiationInterface → DifferentiationInterfaceFiniteDiffExt
#   13353.3 ms  ✓ Static
#    1906.3 ms  ✓ FiniteDiff → FiniteDiffSparseArraysExt
#    1937.1 ms  ✓ FiniteDiff → FiniteDiffStaticArraysExt
#    8380.7 ms  ✓ Accessors
#   11542.9 ms  ✓ ForwardDiff
#    1467.7 ms  ✓ BitTwiddlingConvenienceFunctions
#    7956.0 ms  ✓ StatsFuns
#    1737.9 ms  ✓ Accessors → TestExt
#   16121.6 ms  ✓ SparseMatrixColorings
#    1592.4 ms  ✓ Accessors → StaticArraysExt
#    1410.2 ms  ✓ Accessors → LinearAlgebraExt
#    3021.0 ms  ✓ CPUSummary
#    1294.1 ms  ✓ FastPower → FastPowerForwardDiffExt
#    2063.3 ms  ✓ ForwardDiff → ForwardDiffStaticArraysExt
#    1434.3 ms  ✓ PreallocationTools → PreallocationToolsForwardDiffExt
#    1350.2 ms  ✓ StatsFuns → StatsFunsInverseFunctionsExt
#    2408.3 ms  ✓ Interpolations → InterpolationsForwardDiffExt
#    5840.4 ms  ✓ NLSolversBase
#   13103.3 ms  ✓ Graphs
#    1672.9 ms  ✓ DifferentiationInterface → DifferentiationInterfaceSparseMatrixColoringsExt
#    2289.6 ms  ✓ SparseMatrixColorings → SparseMatrixColoringsColorsExt
#   13625.0 ms  ✓ SparseConnectivityTracer
#    3711.4 ms  ✓ StatsFuns → StatsFunsChainRulesCoreExt
#    4889.5 ms  ✓ DifferentiationInterface → DifferentiationInterfaceForwardDiffExt
#    1532.7 ms  ✓ PolyesterWeave
#    1430.3 ms  ✓ SparseConnectivityTracer → SparseConnectivityTracerChainRulesCoreExt
#    1935.6 ms  ✓ SparseConnectivityTracer → SparseConnectivityTracerLogExpFunctionsExt
#    2358.7 ms  ✓ Graphs → GraphsSharedArraysExt
#    2524.2 ms  ✓ SparseConnectivityTracer → SparseConnectivityTracerNaNMathExt
#    5749.0 ms  ✓ SciMLOperators
#    5158.8 ms  ✓ SymbolicIndexingInterface
#    1468.6 ms  ✓ DifferentiationInterface → DifferentiationInterfaceSparseConnectivityTracerExt
#    1443.3 ms  ✓ PreallocationTools → PreallocationToolsSparseConnectivityTracerExt
#    4697.8 ms  ✓ LineSearches
#    1154.9 ms  ✓ SciMLOperators → SciMLOperatorsStaticArraysCoreExt
#    1949.2 ms  ✓ SciMLOperators → SciMLOperatorsSparseArraysExt
#    3206.4 ms  ✓ SparseConnectivityTracer → SparseConnectivityTracerSpecialFunctionsExt
#    2280.5 ms  ✓ SymbolicIndexingInterface → SymbolicIndexingInterfacePrettyTablesExt
#   10134.8 ms  ✓ Distributions
#    2647.4 ms  ✓ Distributions → DistributionsTestExt
#   16790.7 ms  ✓ StaticArrayInterface
#    1041.1 ms  ✓ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#    1073.6 ms  ✓ CloseOpenIntervals
#    1342.6 ms  ✓ LayoutPointers
#    1390.5 ms  ✓ StaticArrayInterface → StaticArrayInterfaceStaticArraysExt
#    4857.8 ms  ✓ Distributions → DistributionsChainRulesCoreExt
#    1769.3 ms  ✓ StrideArraysCore
#   23204.6 ms  ✓ Moshi
#    1149.2 ms  ✓ Polyester
#   28595.5 ms  ✓ ArrayLayouts
#   11497.8 ms  ✓ RecursiveArrayTools
#    1891.2 ms  ✓ FastBroadcast
#    1578.4 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsTablesExt
#    1633.5 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsForwardDiffExt
#    1668.9 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsStatisticsExt
#   19127.5 ms  ✓ QuasiMonteCarlo
#    2206.5 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsSparseArraysExt
#    2377.2 ms  ✓ TaylorSeries → TaylorSeriesRATExt
#    1764.2 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsFastBroadcastExt
#    3367.9 ms  ✓ ArrayLayouts → ArrayLayoutsSparseArraysExt
#    2002.0 ms  ✓ QuasiMonteCarlo → QuasiMonteCarloDistributionsExt
#    6145.4 ms  ✓ MatrixFactorizations
#    1960.7 ms  ✓ MonteCarloIntegration
#    3959.1 ms  ✓ LazyArrays
#    1872.1 ms  ✓ LazyArrays → LazyArraysStaticArraysExt
#   42277.0 ms  ✓ ExponentialUtilities
#    3101.8 ms  ✓ ExponentialUtilities → ExponentialUtilitiesStaticArraysExt
#   18592.7 ms  ✓ SciMLBase
#   21297.7 ms  ✓ BandedMatrices
#    1543.1 ms  ✓ SciMLBase → SciMLBaseDifferentiationInterfaceExt
#    1700.6 ms  ✓ SciMLBase → SciMLBaseChainRulesCoreExt
#    2395.2 ms  ✓ SciMLBase → SciMLBaseDistributionsExt
#    2506.9 ms  ✓ FiniteDiff → FiniteDiffBandedMatricesExt
#    2552.6 ms  ✓ ArrayInterface → ArrayInterfaceBandedMatricesExt
#    2796.3 ms  ✓ MatrixFactorizations → MatrixFactorizationsBandedMatricesExt
#    2904.1 ms  ✓ BandedMatrices → BandedMatricesSparseArraysExt
#    3736.9 ms  ✓ SciMLBase → SciMLBaseForwardDiffExt
#    4339.9 ms  ✓ LazyArrays → LazyArraysBandedMatricesExt
#    4010.9 ms  ✓ Integrals
#    5943.7 ms  ✓ SciMLJacobianOperators
#    6056.8 ms  ✓ OptimizationBase
#     720.0 ms  ✓ OptimizationBase → OptimizationFiniteDiffExt
#     880.4 ms  ✓ OptimizationBase → OptimizationForwardDiffExt
#    2956.0 ms  ✓ Integrals → IntegralsFastGaussQuadratureExt
#    4640.2 ms  ✓ Integrals → IntegralsDifferentiationInterfaceExt
#    4720.9 ms  ✓ Integrals → IntegralsForwardDiffExt
#    6885.6 ms  ✓ LineSearch
#   11008.4 ms  ✓ FastAlmostBandedMatrices
#    1767.4 ms  ✓ LineSearch → LineSearchLineSearchesExt
#   10994.7 ms  ✓ NonlinearSolveBase
#    1765.1 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseLineSearchExt
#    1775.5 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseChainRulesCoreExt
#    2100.0 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseSparseMatrixColoringsExt
#    2202.3 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseSparseArraysExt
#    2441.9 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseForwardDiffExt
#    3363.4 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseBandedMatricesExt
#    6007.3 ms  ✓ BracketingNonlinearSolve
#    1537.0 ms  ✓ BracketingNonlinearSolve → BracketingNonlinearSolveForwardDiffExt
#    1849.6 ms  ✓ BracketingNonlinearSolve → BracketingNonlinearSolveChainRulesCoreExt
#    4210.8 ms  ✓ DiffEqBase
#    2303.3 ms  ✓ DiffEqBase → DiffEqBaseChainRulesCoreExt
#    2470.3 ms  ✓ DiffEqBase → DiffEqBaseSparseArraysExt
#    2495.5 ms  ✓ DiffEqBase → DiffEqBaseForwardDiffExt
#   12264.8 ms  ✓ NonlinearSolveSpectralMethods
#    2189.2 ms  ✓ NonlinearSolveSpectralMethods → NonlinearSolveSpectralMethodsForwardDiffExt
#    4682.3 ms  ✓ DiffEqNoiseProcess
#    7729.4 ms  ✓ OrdinaryDiffEqCore
#    8686.0 ms  ✓ DiffEqCallbacks
#    3699.0 ms  ✓ OrdinaryDiffEqCore → OrdinaryDiffEqCoreSparseArraysExt
#    5719.0 ms  ✓ OrdinaryDiffEqFunctionMap
#    6074.0 ms  ✓ OrdinaryDiffEqQPRK
#   16871.1 ms  ✓ SimpleNonlinearSolve
#    6993.0 ms  ✓ OrdinaryDiffEqPRK
#    7036.5 ms  ✓ OrdinaryDiffEqRKN
#    6120.9 ms  ✓ OrdinaryDiffEqSymplecticRK
#    7287.6 ms  ✓ OrdinaryDiffEqExplicitRK
#    7424.2 ms  ✓ OrdinaryDiffEqStabilizedRK
#    7546.7 ms  ✓ OrdinaryDiffEqHighOrderRK
#    8047.1 ms  ✓ OrdinaryDiffEqSSPRK
#    2512.8 ms  ✓ SimpleNonlinearSolve → SimpleNonlinearSolveChainRulesCoreExt
#    5513.3 ms  ✓ OrdinaryDiffEqFeagin
#    8346.8 ms  ✓ OrdinaryDiffEqLowOrderRK
#    5789.0 ms  ✓ JumpProcesses
#    5799.4 ms  ✓ OrdinaryDiffEqLinear
#    5879.5 ms  ✓ SteadyStateDiffEq
#    6818.2 ms  ✓ OrdinaryDiffEqLowStorageRK
#   14536.3 ms  ✓ OrdinaryDiffEqTsit5
#   50464.1 ms  ✓ LinearSolve
#    5272.8 ms  ✓ OrdinaryDiffEqAdamsBashforthMoulton
#    3781.8 ms  ✓ OrdinaryDiffEqNordsieck
#    4560.7 ms  ✓ LinearSolve → LinearSolveBandedMatricesExt
#    4669.1 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseLinearSolveExt
#    5371.5 ms  ✓ LinearSolve → LinearSolveForwardDiffExt
#    5432.2 ms  ✓ LinearSolve → LinearSolveFastAlmostBandedMatricesExt
#    6566.7 ms  ✓ LinearSolve → LinearSolveSparseArraysExt
#    3410.6 ms  ✓ LinearSolve → LinearSolveEnzymeExt
#    8219.4 ms  ✓ OrdinaryDiffEqDifferentiation
#    3685.1 ms  ✓ OrdinaryDiffEqDifferentiation → OrdinaryDiffEqDifferentiationSparseArraysExt
#    8193.5 ms  ✓ OrdinaryDiffEqExponentialRK
#    9286.4 ms  ✓ OrdinaryDiffEqExtrapolation
#   22731.4 ms  ✓ Sundials
#   27251.1 ms  ✓ NonlinearSolveQuasiNewton
#   46240.0 ms  ✓ OrdinaryDiffEqVerner
#    3790.9 ms  ✓ NonlinearSolveQuasiNewton → NonlinearSolveQuasiNewtonForwardDiffExt
#   40201.8 ms  ✓ NonlinearSolveFirstOrder
#   33633.9 ms  ✓ OrdinaryDiffEqRosenbrock
#    9446.5 ms  ✓ BoundaryValueDiffEqCore
#    9122.4 ms  ✓ BoundaryValueDiffEqAscher
#   11677.2 ms  ✓ BoundaryValueDiffEqMIRKN
#   21144.1 ms  ✓ NonlinearSolve
#    4268.9 ms  ✓ NonlinearSolve → NonlinearSolveSundialsExt
#    6230.8 ms  ✓ OrdinaryDiffEqNonlinearSolve
#    7219.8 ms  ✓ OrdinaryDiffEqIMEXMultistep
#    7317.5 ms  ✓ OrdinaryDiffEqStabilizedIRK
#    8125.3 ms  ✓ OrdinaryDiffEqPDIRK
#    9386.1 ms  ✓ OrdinaryDiffEqSDIRK
#   11282.4 ms  ✓ StochasticDiffEq
#   16584.5 ms  ✓ OrdinaryDiffEqBDF
#   31143.6 ms  ✓ OrdinaryDiffEqFIRK
#   35475.0 ms  ✓ OrdinaryDiffEqDefault
#    6256.3 ms  ✓ OrdinaryDiffEq
#    9763.8 ms  ✓ DelayDiffEq
#  120554.4 ms  ✓ BoundaryValueDiffEqMIRK
#  129363.8 ms  ✓ BoundaryValueDiffEqShooting
#  169802.2 ms  ✓ BoundaryValueDiffEqFIRK
#    7834.0 ms  ✓ BoundaryValueDiffEq
#   10301.5 ms  ✓ DifferentialEquations
#   252 dependencies successfully precompiled in 360 seconds. 255 already precompiled.
#   1 dependency had output during precompilation:
# ┌ LinearSolve
# │   Downloading artifact: MKL
# └

# %%
using DifferentialEquations

# %%
Pkg.add("Roots")
# Out:
#    Resolving package versions...
#    Installed Roots ─ v2.2.11
#     Updating `~/.julia/environments/v1.12/Project.toml`
#   [f2b01f46] + Roots v2.2.11
#     Updating `~/.julia/environments/v1.12/Manifest.toml`
#   [f2b01f46] + Roots v2.2.11
# Precompiling packages...
#    3891.1 ms  ✓ Roots
#     554.2 ms  ✓ Roots → RootsChainRulesCoreExt
#     619.9 ms  ✓ Roots → RootsForwardDiffExt
#   3 dependencies successfully precompiled in 7 seconds. 507 already precompiled.

# %%
using Roots

# %%
Pkg.add("ForwardDiff")
# Out:
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.12/Project.toml`
#   [f6369f11] + ForwardDiff v1.3.2
#     Manifest No packages added to or removed from `~/.julia/environments/v1.12/Manifest.toml`

# %%
using ForwardDiff
